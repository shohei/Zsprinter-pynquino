# %%
from metakernel import register_ipython_magics
register_ipython_magics()

# %%
# %jigsaw Python --workspace initHW
# Out:
# <iframe src="initHW.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace gcode_homing
# Out:
# <iframe src="gcode_homing.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
arduino.write("G28\n")

# %%
# %jigsaw Python --workspace send_gcode_string2
# Out:
# <iframe src="send_gcode_string2.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
arduino.write("G1 X10\n")

# %%
# %jigsaw Python --workspace send_gcode_file
# Out:
# <iframe src="send_gcode_file.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
#import time
#arduino.write('G1 Z0.325 F3000\n')
print("open file")
with open('data/20mm_cube.gcode') as file:
    lines = file.readlines()
    for idx,line in enumerate(lines):
        cmd = line.strip()+'\n'
        if(cmd[0]==';'):
            continue
        print(idx,line)
        arduino.write(cmd)
# Out:
# open file
# 204 G1 X14.750 Y-11.806 F9000
#
# 205 G1 Z0.225 F1200
#
# 206 G1 E0.0000 F1080
#
# 207 G92 E0
#
# 208 G1 X14.750 Y11.806 E1.2271 F1500
#
# 209 G1 X14.636 Y12.082 E1.2426
#
# 210 G1 X12.082 Y14.636 E1.4303
#
# 211 G1 X11.806 Y14.750 E1.4458
#
# 212 G1 X-11.806 Y14.750 E2.6729
#
# 213 G1 X-12.082 Y14.636 E2.6884
#
# 214 G1 X-14.636 Y12.082 E2.8761
#
# 215 G1 X-14.750 Y11.806 E2.8916
#
# 216 G1 X-14.750 Y-11.806 E4.1187
#
# 217 G1 X-14.636 Y-12.082 E4.1342
#
# 218 G1 X-12.082 Y-14.636 E4.3220
#
# 219 G1 X-11.806 Y-14.750 E4.3375
#
# 220 G1 X11.806 Y-14.750 E5.5646
#
# 221 G1 X12.082 Y-14.636 E5.5801
#
# 222 G1 X14.636 Y-12.082 E5.7678
#
# 223 G1 X14.750 Y-11.806 E5.7833
#
# 224 G1 X14.250 Y-11.707 F9000
#
# 225 G92 E0
#
# 226 G1 X14.250 Y11.707 E1.2168 F1500

# %%
# %jigsaw Python --workspace video_setup
# Out:
# <iframe src="video_setup.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace video_pipeline4
# Out:
# <iframe src="video_pipeline4.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace video_reset
# Out:
# <iframe src="video_reset.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace gamepad
# Out:
# <iframe src="gamepad.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace movidius
# Out:
# <iframe src="movidius.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace reset_movidius
# Out:
# <iframe src="reset_movidius.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace filter2d_initHW
# Out:
# <iframe src="filter2d_initHW.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace soft_filter2d
# Out:
# <iframe src="soft_filter2d.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace hw_filter2d
# Out:
# <iframe src="hw_filter2d.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace binarize
# Out:
# <iframe src="binarize.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace center_and_angle
# Out:
# <iframe src="center_and_angle.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace center_and_angle_continuous
# Out:
# <iframe src="center_and_angle_continuous.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>

# %%
# %jigsaw Python --workspace center_and_angle_continuous_gcode
# Out:
# <iframe src="center_and_angle_continuous_gcode.html" width="100%" height="450" style="resize: both; overflow: auto;"></iframe>
# [object Object]

# %%
arduino.write("G28\n")
